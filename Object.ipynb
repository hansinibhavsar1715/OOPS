# %% [markdown]
# object

# %%
class Student:
  def __init__(self, name, marks):
    self.name = name
    self.marks = marks
  def show(self):
    print("Name:", self.name)
    print("Marks:", self.marks)
s1=Student("John", 89)
s1.show()
# Out:
# Name: John
# Marks: 89

# %% [markdown]
# Multiple Object

# %%
class Student:
  def __init__(self, name, marks):
    self.name = name
    self.marks = marks
  def show(self):
    print("name:", self.name)
    print("marks:", self.marks)
    print("...............")
  s1 = Student("John", 89)
  s2 = Student("Tom", 68)
  s3 = Student("Sara", 90)
  s1.show()
  s2.show()
  s3.show()
# Out:
# Name: John
# Marks: 89
# Name: Tom
# Marks: 68
# Name: Sara
# Marks: 90
